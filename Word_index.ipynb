# %%
import ffn
# %matplotlib inline

# %%
data = ffn.get('^GDAXI,^IXIC,^FCHI,^FTSE', start='2024-01-01', end='2024-01-01')
print(data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   gdaxi         ixic         fchi         ftse
# Date
# 2010-01-04  6048.299805  2308.419922  4013.969971  5500.299805
# 2010-01-05  6031.859863  2308.709961  4012.909912  5522.500000
# 2010-01-06  6034.330078  2301.090088  4017.669922  5530.000000
# 2010-01-07  6019.359863  2300.050049  4024.800049  5526.700195
# 2010-01-08  6037.609863  2317.169922  4045.139893  5534.200195

# %%
returns = data.to_log_returns().dropna()
print(returns.head())
# Out:
#                gdaxi      ixic      fchi      ftse
# Date
# 2010-01-05 -0.002722  0.000126 -0.000264  0.004028
# 2010-01-06  0.000409 -0.003306  0.001185  0.001357
# 2010-01-07 -0.002484 -0.000452  0.001773 -0.000597
# 2010-01-08  0.003027  0.007416  0.005041  0.001356
# 2010-01-11  0.000479 -0.002056 -0.000507  0.000704

# %%
ax = returns.hist(figsize=(12, 8))

# %%
returns.corr().as_format('.2f')
# Out:
#       gdaxi  ixic  fchi  ftse
# gdaxi  1.00  0.56  0.94  0.84
# ixic   0.56  1.00  0.55  0.51
# fchi   0.94  0.55  1.00  0.87
# ftse   0.84  0.51  0.87  1.00

# %%
returns.plot_corr_heatmap();

# %%
ax = data.rebase().plot(figsize=(12,5))

# %% [markdown]
# **Performance Measurement**

# %%
perf = data.calc_stats()
perf.plot();

# %%
print(perf.display())
# Out:
# Stat                 gdaxi       ixic        fchi        ftse
# -------------------  ----------  ----------  ----------  ----------
# Start                2010-01-04  2010-01-04  2010-01-04  2010-01-04
# End                  2023-12-29  2023-12-29  2023-12-29  2023-12-29
# Risk-free rate       0.00%       0.00%       0.00%       0.00%
#
# Total Return         176.96%     550.29%     87.92%      40.60%
# Daily Sharpe         0.47        0.77        0.33        0.24
# Daily Sortino        0.75        1.22        0.52        0.37
# CAGR                 7.56%       14.33%      4.62%       2.47%
# Max Drawdown         -38.78%     -36.40%     -38.56%     -36.61%
# Calmar Ratio         0.19        0.39        0.12        0.07
#
# MTD                  3.31%       5.52%       3.18%       3.75%
# 3m                   8.87%       13.56%      5.72%       1.64%
# 6m                   5.05%       10.45%      3.15%       3.50%
# YTD                  20.31%      43.42%      16.52%      3.78%
# ...

# %%
perf[2].plot_histogram();

# %%
stats = data.calc_stats()
stats.display()
# Out:
# Stat                 gdaxi       ixic        fchi        ftse
# -------------------  ----------  ----------  ----------  ----------
# Start                2010-01-04  2010-01-04  2010-01-04  2010-01-04
# End                  2023-12-29  2023-12-29  2023-12-29  2023-12-29
# Risk-free rate       0.00%       0.00%       0.00%       0.00%
#
# Total Return         176.96%     550.29%     87.92%      40.60%
# Daily Sharpe         0.47        0.77        0.33        0.24
# Daily Sortino        0.75        1.22        0.52        0.37
# CAGR                 7.56%       14.33%      4.62%       2.47%
# Max Drawdown         -38.78%     -36.40%     -38.56%     -36.61%
# Calmar Ratio         0.19        0.39        0.12        0.07
#
# MTD                  3.31%       5.52%       3.18%       3.75%
# 3m                   8.87%       13.56%      5.72%       1.64%
# 6m                   5.05%       10.45%      3.15%       3.50%
# YTD                  20.31%      43.42%      16.52%      3.78%
# ...

# %%
ax = stats.prices.to_drawdown_series().plot(figsize=(10, 5))

# %%
perf['fchi'].stats
# Out:
# start                    2010-01-04 00:00:00
# end                      2023-12-29 00:00:00
# rf                                       0.0
# total_return                        0.879232
# cagr                                0.046152
# max_drawdown                       -0.385585
# calmar                              0.119694
# mtd                                  0.03179
# three_month                         0.057199
# six_month                           0.031514
# ytd                                 0.165193
# one_year                            0.147519
# three_year                           0.10369
# five_year                           0.099978
# ten_year                            0.058436
# incep                               0.046152
# daily_sharpe                        0.329272
# daily_sortino                       0.519775
# daily_mean                          0.067852
# daily_vol                           0.206067
# daily_skew                         -0.316455
# ...
